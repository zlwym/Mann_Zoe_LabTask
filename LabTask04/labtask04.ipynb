# %% [markdown]
# <a href="https://colab.research.google.com/github/zlwym/Mann_Zoe_LabTask/blob/main/labtask04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("youtube_videos.csv")

# %%
df.head()
# Out:
#    video_id                                              title category  \
# 0  vid_0000  I tried EVERY transformers tool — the WINNER s...    Music
# 1  vid_0001         What nobody tells you about AI image tools   Gaming
# 2  vid_0002  What nobody tells you about machine learning p...   Gaming
# 3  vid_0003                        Is Claude worth it in 2025?   Gaming
# 4  vid_0004  URGENT: voice cloning AI is about to CHANGE FO...    Music
#
#   channel_tier upload_day  upload_hour  duration_seconds    views  likes  \
# 0          Mid     Sunday            0               721   228102   9979
# 1        Small   Saturday           21              1894    25078    962
# 2        Large     Monday           18              1413  1323949   6619
# 3          Mid   Thursday           14              1335   187752   4936
# 4        Small     Monday            4              3158    12583    777
#
#    comments  shares  watch_time_minutes  avg_view_duration_seconds  \
# ...

# %%
df["subscribers"]
# Out:
# 0       441016
# 1        25339
# 2      2398429
# 3       498144
# 4        30039
#         ...
# 205      13428
# 206      10005
# 207     483919
# 208      11937
# 209     553531
# Name: subscribers, Length: 210, dtype: int64

# %%
scaler = MinMaxScaler()

# %%
df["subscribers_minmax"] = scaler.fit_transform(df[["subscribers"]])

# %%
df["subscribers"].describe()
# Out:
# count    2.100000e+02
# mean     1.005263e+06
# std      2.063624e+06
# min      5.624000e+03
# 25%      2.544875e+04
# 50%      1.359100e+05
# 75%      4.862028e+05
# max      7.763623e+06
# Name: subscribers, dtype: float64

# %%
standard_scaler = StandardScaler()

# %%
df["view_zscore"] = standard_scaler.fit_transform(df[["views"]])

# %%
df[["views", "view_zscore"]]
